# %% [markdown]
# <a href="https://colab.research.google.com/github/LoPA607/tensorflow_power/blob/main/dropout_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("sonar_dataset.csv", header=None)
df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 141  0.0707  0.1252  0.1447  0.1644  0.1693  0.0844  0.0715  0.0947  0.1583
# 199  0.0116  0.0744  0.0367  0.0225  0.0076  0.0545  0.1110  0.1069  0.1708
# 176  0.0635  0.0709  0.0453  0.0333  0.0185  0.1260  0.1015  0.1918  0.3362
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 9    0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
#
#          9   ...      51      52      53      54      55      56      57  \
# 141  0.1247  ...  0.0156  0.0197  0.0135  0.0127  0.0138  0.0133  0.0131
# 199  0.2271  ...  0.0141  0.0103  0.0100  0.0034  0.0026  0.0037  0.0044
# 176  0.3900  ...  0.0048  0.0025  0.0087  0.0072  0.0095  0.0086  0.0085
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 9    0.0251  ...  0.0090  0.0223  0.0179  0.0084  0.0068  0.0032  0.0035
#
#          58      59  60
# 141  0.0154  0.0218   M
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
X=df.drop(60, axis='columns')
y=df[60]
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
y=pd.get_dummies(y,drop_first=True)
y.sample(5)
# Out:
#          R
# 92    True
# 176  False
# 34    True
# 71    True
# 48    True

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25, random_state=1)

# %%
X_train.shape
# Out:
# (156, 60)

# %%
X_test.shape
# Out:
# (52, 60)

# %%
y_train.shape
# Out:
# (156, 1)

# %%
y_test.shape
# Out:
# (52, 1)

# %%
model=keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 4ms/step - loss: 0.6916 - accuracy: 0.5321
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6752 - accuracy: 0.5577
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.5641
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6493 - accuracy: 0.6410
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6383 - accuracy: 0.7051
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6121 - accuracy: 0.6603
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5791 - accuracy: 0.8141
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7500
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5073 - accuracy: 0.8269
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7ae9e8211cf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 12ms/step - loss: 1.1070 - accuracy: 0.7308
# [1.106979489326477, 0.7307692170143127]

# %%
y_predict=model.predict(X_test).reshape(-1)
print(y_predict[:10])

y_predict=np.round(y_predict)
print(y_predict[:10])
# Out:
# 2/2 [==============================] - 0s 6ms/step
# [2.1742893e-07 9.9983042e-01 9.8337275e-01 1.1563109e-04 9.9999851e-01
#  9.9997514e-01 3.0324817e-01 9.9999893e-01 1.0954880e-04 9.9999946e-01]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]

# %%
y_test[:10]
# Out:
#          R
# 186  False
# 155  False
# 165  False
# 200  False
# 58    True
# 34    True
# 151  False
# 18    True
# 202  False
# 62    True

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.70      0.85      0.77        27
#         True       0.79      0.60      0.68        25
#
#     accuracy                           0.73        52
#    macro avg       0.74      0.73      0.72        52
# weighted avg       0.74      0.73      0.73        52

# %%
modeld=keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')
])
modeld.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modeld.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.7069 - accuracy: 0.5064
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6891 - accuracy: 0.5128
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7277 - accuracy: 0.4423
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6952 - accuracy: 0.5449
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.4615
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.5192
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7187 - accuracy: 0.5000
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5385
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5385
# Epoch 10/100
# ...

# %%
modeld.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7ae9de744940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4659 - accuracy: 0.7500
# [0.4659067988395691, 0.75]

# %%
y_pred=modeld.predict(X_test).reshape(-1)
y_pred=np.round(y_pred)
print(classification_report(y_test,y_pred))
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ae9de7460e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#        False       0.72      0.85      0.78        27
#         True       0.80      0.64      0.71        25
#
#     accuracy                           0.75        52
# ...

# %% [markdown]
# IT Is not sure but will likely improve
